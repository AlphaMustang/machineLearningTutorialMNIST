# %% [markdown]
# # Classifying Handwritten Digits from the MNIST Dataset Using a Multi-Layer Perceptron (Neural Network)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read in the data

# %%
import idx2numpy as idx

X_train = idx.convert_from_file('./data/train-images-idx3-ubyte')
X_test = idx.convert_from_file('./data/t10k-images-idx3-ubyte')
Y_train = idx.convert_from_file('./data/train-labels-idx1-ubyte')
Y_test = idx.convert_from_file('./data/t10k-labels-idx1-ubyte')

# %%
print(trainingData.shape)
for i in range(69):
    image = X_train[i,:,:]
    image = image.reshape((28,28))
    plt.imshow(image, cmap='gray')
    plt.title("Label = " + str(Y_train[i]))
    plt.show()
# Out:
# (60000, 28, 28)

# %% [markdown]
# ## Creating a Neural Network with two hidden layers

# %%
from sklearn.neural_network import MLPClassifier

X_train = X_train.reshape((60000,784))
clf = MLPClassifier(hidden_layer_sizes=(300,100), activation='relu', solver='sgd')
clf.fit(X_train, Y_train)
predictions = clf.predict(X_test.reshape(10000,784))

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, predictions))
# Out:
# 0.9616

# %% [markdown]
# ## Creating a Neural Network with four hidden layers

# %%
from sklearn.neural_network import MLPClassifier

X_train = X_train.reshape((60000,784))
clf = MLPClassifier(hidden_layer_sizes=(300,200,100,50), activation='relu', solver='sgd')
clf.fit(X_train, Y_train)
predictions = clf.predict(X_test.reshape(10000,784))

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, predictions))
# Out:
# 0.9706
